# %%
import math
from matplotlib import pyplot as plt
import numpy as np

# %%
data = np.zeros((101,2))
for x in range(0,100):
    data[x][0] = x-50
    data[x][1] = math.sin(x-50)

    
plt.plot(data)
plt.show
print (data)
# Out:
# [[-5.00000000e+01  2.62374854e-01]
#  [-4.90000000e+01  9.53752653e-01]
#  [-4.80000000e+01  7.68254661e-01]
#  [-4.70000000e+01 -1.23573123e-01]
#  [-4.60000000e+01 -9.01788348e-01]
#  [-4.50000000e+01 -8.50903525e-01]
#  [-4.40000000e+01 -1.77019251e-02]
#  [-4.30000000e+01  8.31774743e-01]
#  [-4.20000000e+01  9.16521548e-01]
#  [-4.10000000e+01  1.58622669e-01]
#  [-4.00000000e+01 -7.45113160e-01]
#  [-3.90000000e+01 -9.63795386e-01]
#  [-3.80000000e+01 -2.96368579e-01]
#  [-3.70000000e+01  6.43538133e-01]
#  [-3.60000000e+01  9.91778853e-01]
#  [-3.50000000e+01  4.28182669e-01]
#  [-3.40000000e+01 -5.29082686e-01]
#  [-3.30000000e+01 -9.99911860e-01]
#  [-3.20000000e+01 -5.51426681e-01]
#  [-3.10000000e+01  4.04037645e-01]
#  [-3.00000000e+01  9.88031624e-01]
#  [-2.90000000e+01  6.63633884e-01]
#  [-2.80000000e+01 -2.70905788e-01]
#  [-2.70000000e+01 -9.56375928e-01]
#  [-2.60000000e+01 -7.62558450e-01]
#  [-2.50000000e+01  1.32351750e-01]
#  [-2.40000000e+01  9.05578362e-01]
# ...

# %%
x = np.linspace(0.1,10,100)
y = np.log(x)
plt.plot(x,y)
plt.show()
